# %%
import pandas as pd
import numpy as np

data = pd.read_csv("C:\Python38\Epileptic Seizure Recognition.csv")
data.head()  #to print the initial five rows of the whole Dataset
# Out:
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
data.info() #to get the information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %%
data.describe() #to get the stats of the data
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
#data Preprocessing
data.isnull()   #to check whether There are null values in any row for any variable
# Out:
#        Unnamed     X1     X2     X3     X4     X5     X6     X7     X8     X9  \
# 0        False  False  False  False  False  False  False  False  False  False
# 1        False  False  False  False  False  False  False  False  False  False
# 2        False  False  False  False  False  False  False  False  False  False
# 3        False  False  False  False  False  False  False  False  False  False
# 4        False  False  False  False  False  False  False  False  False  False
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 11495    False  False  False  False  False  False  False  False  False  False
# 11496    False  False  False  False  False  False  False  False  False  False
# 11497    False  False  False  False  False  False  False  False  False  False
# 11498    False  False  False  False  False  False  False  False  False  False
# 11499    False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed    0
# X1         0
# X2         0
# X3         0
# X4         0
#           ..
# X175       0
# X176       0
# X177       0
# X178       0
# y          0
# Length: 180, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.columns
# Out:
# Index(['Unnamed', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        ...
#        'X170', 'X171', 'X172', 'X173', 'X174', 'X175', 'X176', 'X177', 'X178',
#        'y'],
#       dtype='object', length=180)

# %%
Col=data.columns  #storing all the Column names in a variable

# %%
dep_var=data.y
dep_var.unique()  #identifying the unique values
# Out:
# array([4, 1, 5, 2, 3], dtype=int64)

# %%
dep_var
# Out:
# 0        4
# 1        1
# 2        5
# 3        5
# 4        5
#         ..
# 11495    2
# 11496    1
# 11497    5
# 11498    3
# 11499    4
# Name: y, Length: 11500, dtype: int64

# %%
dep_var.value_counts() #to count How many times a particular value present in that variable
# Out:
# 5    2300
# 4    2300
# 3    2300
# 2    2300
# 1    2300
# Name: y, dtype: int64

# %%
in_var=data.iloc[:,1:179].values #storing all the independent variable from the Dataset

plt.subplot(511)
plt.plot(in_var[1,:])
plt.title('Classes')
plt.ylabel('uV')
plt.subplot(512)
plt.plot(in_var[7,:])

plt.xlabel('Samples')
# Out:
# Text(0.5,0,'Samples')

# %%
#dividing Training and Testing data

from sklearn.preprocessing import StandardScaler
